# %% [markdown]
# # Data exploration, now with 2020 data

# %%
import pandas as pd

# %%
df = pd.read_csv('2018-2020 modeling data.csv')

# %%
df.head()
# Out:
#   FieldID        Date  Year Province SamplerNo SamplerType  ExtractionGroup  \
# 0    1904  2019-07-05  2019  Alberta        08     Burkard              NaN
# 1    1904  2019-07-06  2019  Alberta        08     Burkard              NaN
# 2    1904  2019-07-07  2019  Alberta        08     Burkard              NaN
# 3    1904  2019-07-08  2019  Alberta        08     Burkard              NaN
# 4    1904  2019-07-09  2019  Alberta        08     Burkard              NaN
#
#   qPCR_Plate  JDay SampleID  ... MinDP_1d  MeanSoilTemp  DiffMeanSoilT  \
# 0   Plate 13   186  T08-186  ...      NaN      15.51667            NaN
# 1   Plate 13   187  T08-187  ...      8.8      19.87917        4.36250
# 2   Plate 13   188  T08-188  ...      9.2      17.97917       -1.90000
# 3   Plate 13   189  T08-189  ...      9.7      17.86250       -0.11667
# 4   Plate 13   190  T08-190  ...      8.4      19.83333        1.97083
#
#    MeanSoilT_1d  MaxSoilTemp  DiffMaxSoilT  MaxSoilT_1d MinSoilTemp  \
# ...
